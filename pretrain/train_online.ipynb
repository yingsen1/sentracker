# %%
###### from train_config import *
from train_sentrack import *

# %%
trainOpt._parse()
# Out:
# ======================user-config========================
# {'batch_frames': 8,
#  'batch_neg': 96,
#  'batch_pos': 32,
#  'ft_layers': ['conv', 'fc', 'mask'],
#  'grad_clip': 10,
#  'img_size': 107,
#  'init_moedel_path': '../models/imagenet-vgg-m.mat',
#  'lr': 0.0001,
#  'lr_mult': {'fc': 10},
#  'model_path': '../models/mdnet_vot-otb_seblock_0903c3gm_01.pth',
#  'momentum': 0.9,
#  'n_cycles': 100,
#  'output_path': 'data/vot-otb.pkl',
#  'overlap_neg': [0, 0.5],
#  'overlap_pos': [0.7, 1],
#  'padding': 16,
#  'seq_home': '../../tracking_benchmark/dataset/',
#  'seqlist_path': 'data/vot-otb.txt',
#  'use_gpu': True,
#  'w_decay': 0.0005}
# =========================end=============================

# %%
# 准备训练数据
from prepro_data import *
# Out:
# vot2013/cup
# 303
# 303
# vot2013/iceskater
# 500
# 500
# vot2013/juice
# 404
# 404
# vot2014/ball
# 602
# 602
# vot2014/bicycle
# 271
# 271
# vot2014/drunk
# 1210
# 1210
# vot2014/fish1
# 436
# 436
# vot2014/hand1
# 244
# 244
# vot2014/polarbear
# 371
# 371
# vot2014/sphere
# 201
# 201
# vot2014/sunshade
# 172
# 172
# vot2014/surfing
# 282
# 282
# vot2014/torus
# 264
# 264
# vot2014/tunnel
# 731
# 731
# vot2016/bag
# 196
# 196
# vot2016/ball1
# 105
# 105
# vot2016/ball2
# 41
# 41
# vot2016/birds1
# 339
# 339
# vot2016/birds2
# 539
# 539
# vot2016/blanket
# 225
# 225
# vot2016/bmx
# 76
# 76
# vot2016/book
# 175
# 175
# vot2016/butterfly
# 151
# 151
# vot2016/crossing
# 131
# 131
# vot2016/dinosaur
# 326
# 326
# vot2016/fernando
# 292
# 292
# vot2016/fish1
# 366
# 366
# vot2016/fish2
# 310
# 310
# vot2016/fish3
# 519
# 519
# vot2016/fish4
# 682
# 682
# vot2016/glove
# 120
# 120
# vot2016/godfather
# 366
# 366
# vot2016/graduate
# 844
# 844
# vot2016/gymnastics1
# 567
# 567
# ...

# %%
train_mdnet()
# Out:
# ../models/imagenet-vgg-m.mat
# ../models/imagenet-vgg-m.mat
# stop
# ==== Start Cycle 0 ====
# Cycle  0, K  0 (57), Loss 105.245, Prec 0.219, Time 0.748
# Cycle  0, K  1 (52), Loss 259.351, Prec 0.281, Time 0.212
# Cycle  0, K  2 (27), Loss 143.919, Prec 0.219, Time 0.209
# Cycle  0, K  3 (21), Loss 236.366, Prec 0.156, Time 0.433
# Cycle  0, K  4 (12), Loss 145.688, Prec 0.219, Time 0.230
# Cycle  0, K  5 (35), Loss 99.600, Prec 0.312, Time 0.426
# Cycle  0, K  6 (13), Loss 162.587, Prec 0.188, Time 0.224
# Cycle  0, K  7 (10), Loss 121.610, Prec 0.219, Time 0.238
# Cycle  0, K  8 (26), Loss 174.871, Prec 0.156, Time 0.230
# Cycle  0, K  9 (53), Loss 122.078, Prec 0.188, Time 0.197
# Cycle  0, K 10 (47), Loss 95.771, Prec 0.281, Time 0.293
# Cycle  0, K 11 ( 0), Loss 218.008, Prec 0.406, Time 0.248
# Cycle  0, K 12 ( 9), Loss 249.264, Prec 0.375, Time 0.252
# Cycle  0, K 13 (14), Loss 166.021, Prec 0.375, Time 0.334
# Cycle  0, K 14 (56), Loss 142.656, Prec 0.281, Time 0.311
# ...

# %%
## 加一个载入得接口

## 每10个epoch保存一次模型

## 创建训练的可视化、mean precision的折线图
